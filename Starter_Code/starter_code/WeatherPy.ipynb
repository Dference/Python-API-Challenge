# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

units = 'metric'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = url + "appid=" + weather_api_key + "&units=" + units + "&q=" + city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
    # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

    # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

    # Append the City information into city_data list
        city_data.append({'City': city, 
                      'Lat': city_lat, 
                      'Lng': city_lng, 
                      'Max Temp': city_max_temp,
                      'Humidity': city_humidity,
                      'Cloudiness': city_clouds,
                      'Wind Speed': city_wind,
                      'Country': city_country,
                      'Date': city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | kingston
# Processing Record 4 of Set 1 | gadzhiyevo
# Processing Record 5 of Set 1 | feijo
# Processing Record 6 of Set 1 | qionghai
# Processing Record 7 of Set 1 | gemena
# Processing Record 8 of Set 1 | bikin
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | piton saint-leu
# Processing Record 13 of Set 1 | serhiyivka
# Processing Record 14 of Set 1 | invercargill
# Processing Record 15 of Set 1 | whakatane
# Processing Record 16 of Set 1 | inverurie
# Processing Record 17 of Set 1 | margaret river
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | klyuchi
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | seven pagodas
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | olonkinbyen
# Processing Record 25 of Set 1 | codrington
# Processing Record 26 of Set 1 | nikolayevsk-on-amure
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | coquimbo
# Processing Record 30 of Set 1 | lihue
# Processing Record 31 of Set 1 | edinburgh of the seven seas
# Processing Record 32 of Set 1 | grytviken
# Processing Record 33 of Set 1 | saipan
# Processing Record 34 of Set 1 | keflavik
# Processing Record 35 of Set 1 | wailua homesteads
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | san julian
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | amurzet
# Processing Record 40 of Set 1 | cole harbour
# Processing Record 41 of Set 1 | richards bay
# Processing Record 42 of Set 1 | sonsorol village
# City not found. Skipping...
# Processing Record 43 of Set 1 | sharanga
# Processing Record 44 of Set 1 | utrik
# Processing Record 45 of Set 1 | tanjung selor
# City not found. Skipping...
# Processing Record 46 of Set 1 | bikenibeu village
# Processing Record 47 of Set 1 | waitangi
# Processing Record 48 of Set 1 | kramators'k
# Processing Record 49 of Set 1 | enewetak
# Processing Record 50 of Set 1 | hawaiian paradise park
# Processing Record 0 of Set 2 | limassol
# Processing Record 1 of Set 2 | kunashak
# Processing Record 2 of Set 2 | paradip garh
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | tura
# Processing Record 5 of Set 2 | chonchi
# Processing Record 6 of Set 2 | nelson bay
# Processing Record 7 of Set 2 | aigues-mortes
# Processing Record 8 of Set 2 | tsiombe
# Processing Record 9 of Set 2 | loreto
# Processing Record 10 of Set 2 | port mathurin
# Processing Record 11 of Set 2 | salem
# Processing Record 12 of Set 2 | ust-nera
# Processing Record 13 of Set 2 | akrehamn
# Processing Record 14 of Set 2 | port saint john's
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | likasi
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | ruiz
# Processing Record 19 of Set 2 | polyarnyy
# Processing Record 20 of Set 2 | donghai
# Processing Record 21 of Set 2 | iskateley
# Processing Record 22 of Set 2 | letterkenny
# Processing Record 23 of Set 2 | zaragoza
# Processing Record 24 of Set 2 | martuk
# Processing Record 25 of Set 2 | isafjordur
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | sassnitz
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | aswan
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | moree
# Processing Record 33 of Set 2 | guarapari
# Processing Record 34 of Set 2 | yuzhno-kurilsk
# Processing Record 35 of Set 2 | chegdomyn
# Processing Record 36 of Set 2 | crane
# Processing Record 37 of Set 2 | mineiros
# Processing Record 38 of Set 2 | bodaybo
# Processing Record 39 of Set 2 | yuxi
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | galesong
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | sakaiminato
# Processing Record 46 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | tarauaca
# Processing Record 0 of Set 3 | anadyr
# Processing Record 1 of Set 3 | tocache
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | qaqortoq
# Processing Record 4 of Set 3 | kirensk
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | west island
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | meulaboh
# Processing Record 9 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | zhangye
# Processing Record 12 of Set 3 | bulancak
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | goshogawara
# Processing Record 15 of Set 3 | kwang binh
# Processing Record 16 of Set 3 | kirakira
# Processing Record 17 of Set 3 | papatowai
# Processing Record 18 of Set 3 | bardai
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | happy valley-goose bay
# Processing Record 21 of Set 3 | cruzilia
# Processing Record 22 of Set 3 | tommot
# Processing Record 23 of Set 3 | sinop
# Processing Record 24 of Set 3 | northam
# Processing Record 25 of Set 3 | levuka
# Processing Record 26 of Set 3 | puerto natales
# Processing Record 27 of Set 3 | vorgashor
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | colares
# Processing Record 30 of Set 3 | morondava
# Processing Record 31 of Set 3 | panacan
# Processing Record 32 of Set 3 | bonthe
# Processing Record 33 of Set 3 | sikeston
# Processing Record 34 of Set 3 | berbera
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | nova sintra
# Processing Record 37 of Set 3 | francistown
# Processing Record 38 of Set 3 | el granada
# Processing Record 39 of Set 3 | altai
# Processing Record 40 of Set 3 | kiunga
# Processing Record 41 of Set 3 | mek'ele
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 3 | tromso
# Processing Record 46 of Set 3 | richfield
# Processing Record 47 of Set 3 | miquelon
# Processing Record 48 of Set 3 | peace river
# Processing Record 49 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 0 of Set 4 | hithadhoo
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | tolanaro
# Processing Record 3 of Set 4 | hammerfest
# Processing Record 4 of Set 4 | portland
# Processing Record 5 of Set 4 | newman
# Processing Record 6 of Set 4 | male
# Processing Record 7 of Set 4 | durban
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | vilyuchinsk
# Processing Record 10 of Set 4 | howrah
# Processing Record 11 of Set 4 | praia da vitoria
# Processing Record 12 of Set 4 | badger
# Processing Record 13 of Set 4 | balkanabat
# Processing Record 14 of Set 4 | bilibino
# Processing Record 15 of Set 4 | natal
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 4 | brookings
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | nuku'alofa
# Processing Record 21 of Set 4 | chincholi
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | lisakovsk
# Processing Record 24 of Set 4 | aasiaat
# Processing Record 25 of Set 4 | manokwari
# Processing Record 26 of Set 4 | nobres
# Processing Record 27 of Set 4 | madinat ash shamal
# Processing Record 28 of Set 4 | punta arenas
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | nantucket
# Processing Record 31 of Set 4 | kuching
# Processing Record 32 of Set 4 | stanley
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | la'ie
# Processing Record 36 of Set 4 | college
# Processing Record 37 of Set 4 | al jawf
# Processing Record 38 of Set 4 | nova vicosa
# Processing Record 39 of Set 4 | novyy urgal
# Processing Record 40 of Set 4 | nushki
# Processing Record 41 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 42 of Set 4 | fort mcmurray
# Processing Record 43 of Set 4 | porto novo
# Processing Record 44 of Set 4 | ryotsu-minato
# Processing Record 45 of Set 4 | live oak
# Processing Record 46 of Set 4 | dehdasht
# Processing Record 47 of Set 4 | daur
# Processing Record 48 of Set 4 | nyurba
# Processing Record 49 of Set 4 | uliastay
# Processing Record 0 of Set 5 | nuuk
# Processing Record 1 of Set 5 | laojunmiao
# Processing Record 2 of Set 5 | callao
# Processing Record 3 of Set 5 | zaysan
# Processing Record 4 of Set 5 | atafu village
# Processing Record 5 of Set 5 | narasannapeta
# Processing Record 6 of Set 5 | huarmey
# Processing Record 7 of Set 5 | severo-yeniseyskiy
# Processing Record 8 of Set 5 | domat
# Processing Record 9 of Set 5 | xinyuan
# Processing Record 10 of Set 5 | poronaysk
# Processing Record 11 of Set 5 | antonio enes
# Processing Record 12 of Set 5 | rundu
# Processing Record 13 of Set 5 | borodulikha
# Processing Record 14 of Set 5 | troitsko-pechorsk
# Processing Record 15 of Set 5 | huocheng
# City not found. Skipping...
# Processing Record 16 of Set 5 | geraldton
# Processing Record 17 of Set 5 | sarupathar
# Processing Record 18 of Set 5 | fort bragg
# Processing Record 19 of Set 5 | san juan
# Processing Record 20 of Set 5 | swainsboro
# Processing Record 21 of Set 5 | labytnangi
# Processing Record 22 of Set 5 | salahonda
# Processing Record 23 of Set 5 | rach gia
# Processing Record 24 of Set 5 | carolina beach
# Processing Record 25 of Set 5 | kondopoga
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | sao vicente
# Processing Record 28 of Set 5 | manaure
# Processing Record 29 of Set 5 | san agustin de valle fertil
# Processing Record 30 of Set 5 | taoudenni
# Processing Record 31 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 5 | laguna
# Processing Record 33 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 34 of Set 5 | gizo
# Processing Record 35 of Set 5 | whitehorse
# Processing Record 36 of Set 5 | obo
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | grande prairie
# Processing Record 39 of Set 5 | gamba
# Processing Record 40 of Set 5 | chemolgan
# Processing Record 41 of Set 5 | remire-montjoly
# Processing Record 42 of Set 5 | monterey
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | festus
# Processing Record 46 of Set 5 | tillaberi
# Processing Record 47 of Set 5 | colonia
# Processing Record 48 of Set 5 | bagaha
# Processing Record 49 of Set 5 | argo
# Processing Record 0 of Set 6 | st. john's
# Processing Record 1 of Set 6 | alesund
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | santa cruz
# Processing Record 4 of Set 6 | tazovsky
# Processing Record 5 of Set 6 | cadale
# Processing Record 6 of Set 6 | zouerate
# Processing Record 7 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 8 of Set 6 | coahuayana de hidalgo
# Processing Record 9 of Set 6 | brisas de zicatela
# Processing Record 10 of Set 6 | roswell
# Processing Record 11 of Set 6 | juan griego
# Processing Record 12 of Set 6 | medellin y madero segunda seccion
# City not found. Skipping...
# Processing Record 13 of Set 6 | prince rupert
# Processing Record 14 of Set 6 | pandan
# Processing Record 15 of Set 6 | hadibu
# Processing Record 16 of Set 6 | ribeira grande
# Processing Record 17 of Set 6 | alice springs
# Processing Record 18 of Set 6 | afaahiti
# Processing Record 19 of Set 6 | el rama
# Processing Record 20 of Set 6 | ust'-ilimsk
# Processing Record 21 of Set 6 | shivpuri
# Processing Record 22 of Set 6 | muravlenko
# Processing Record 23 of Set 6 | gazli
# Processing Record 24 of Set 6 | staroaleyskoye
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | we
# City not found. Skipping...
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | ulladulla
# Processing Record 29 of Set 6 | oroqen zizhiqi
# Processing Record 30 of Set 6 | ampanihy
# Processing Record 31 of Set 6 | gareoult
# Processing Record 32 of Set 6 | eyl
# Processing Record 33 of Set 6 | naperville
# Processing Record 34 of Set 6 | solnechnyy
# Processing Record 35 of Set 6 | angra do heroismo
# Processing Record 36 of Set 6 | tsimlyansk
# Processing Record 37 of Set 6 | at taj
# Processing Record 38 of Set 6 | maine soroa
# Processing Record 39 of Set 6 | walvis bay
# Processing Record 40 of Set 6 | puerto aysen
# Processing Record 41 of Set 6 | manakara
# Processing Record 42 of Set 6 | pacocha
# Processing Record 43 of Set 6 | kerikeri
# Processing Record 44 of Set 6 | chatillon-sur-seine
# Processing Record 45 of Set 6 | nar'yan-mar
# Processing Record 46 of Set 6 | nueva guinea
# Processing Record 47 of Set 6 | bima
# Processing Record 48 of Set 6 | shohimardon
# Processing Record 49 of Set 6 | erenhot
# Processing Record 0 of Set 7 | kathwana
# City not found. Skipping...
# Processing Record 1 of Set 7 | kuqa
# Processing Record 2 of Set 7 | olinda
# Processing Record 3 of Set 7 | ziniare
# Processing Record 4 of Set 7 | fortuna
# Processing Record 5 of Set 7 | thisted
# Processing Record 6 of Set 7 | fale old settlement
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | udachny
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | carrizal
# Processing Record 11 of Set 7 | constantia
# Processing Record 12 of Set 7 | phalodi
# Processing Record 13 of Set 7 | castillos
# Processing Record 14 of Set 7 | port shepstone
# Processing Record 15 of Set 7 | 'ali sabieh
# Processing Record 16 of Set 7 | labrador city
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | lockwood
# Processing Record 19 of Set 7 | vernon
# Processing Record 20 of Set 7 | fukuecho
# Processing Record 21 of Set 7 | kamaishi
# Processing Record 22 of Set 7 | benjamin hill
# Processing Record 23 of Set 7 | yeraliyev
# Processing Record 24 of Set 7 | shangri-la
# City not found. Skipping...
# Processing Record 25 of Set 7 | kourou
# Processing Record 26 of Set 7 | cooper's town
# Processing Record 27 of Set 7 | maros
# City not found. Skipping...
# Processing Record 28 of Set 7 | nemuro
# Processing Record 29 of Set 7 | kasempa
# Processing Record 30 of Set 7 | tlacotepec
# Processing Record 31 of Set 7 | kargasok
# Processing Record 32 of Set 7 | namdrik
# Processing Record 33 of Set 7 | utete
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | san luis de la loma
# Processing Record 36 of Set 7 | maralal
# Processing Record 37 of Set 7 | were ilu
# Processing Record 38 of Set 7 | puerto baquerizo moreno
# Processing Record 39 of Set 7 | morant bay
# Processing Record 40 of Set 7 | durres
# Processing Record 41 of Set 7 | port alberni
# Processing Record 42 of Set 7 | mantua
# Processing Record 43 of Set 7 | saint-philippe
# Processing Record 44 of Set 7 | zhezqazghan
# Processing Record 45 of Set 7 | pingxiang
# Processing Record 46 of Set 7 | vilyuysk
# Processing Record 47 of Set 7 | gisborne
# Processing Record 48 of Set 7 | punto fijo
# Processing Record 49 of Set 7 | sao felix do xingu
# Processing Record 0 of Set 8 | okha
# Processing Record 1 of Set 8 | le port
# Processing Record 2 of Set 8 | pakuranga
# Processing Record 3 of Set 8 | iquique
# Processing Record 4 of Set 8 | letlhakane
# Processing Record 5 of Set 8 | cockburn town
# Processing Record 6 of Set 8 | greenville
# Processing Record 7 of Set 8 | ornskoldsvik
# Processing Record 8 of Set 8 | rehoboth
# Processing Record 9 of Set 8 | akureyri
# Processing Record 10 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 11 of Set 8 | saint-pierre
# Processing Record 12 of Set 8 | saint-louis
# Processing Record 13 of Set 8 | san patricio
# Processing Record 14 of Set 8 | port augusta
# Processing Record 15 of Set 8 | tadine
# Processing Record 16 of Set 8 | cedeira
# Processing Record 17 of Set 8 | maxcanu
# Processing Record 18 of Set 8 | novi sanzhary
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | al ghayzah
# Processing Record 21 of Set 8 | tarawa
# Processing Record 22 of Set 8 | zmeinogorsk
# Processing Record 23 of Set 8 | afif
# Processing Record 24 of Set 8 | pitimbu
# Processing Record 25 of Set 8 | quibdo
# Processing Record 26 of Set 8 | nabire
# Processing Record 27 of Set 8 | brigantine
# Processing Record 28 of Set 8 | gray
# Processing Record 29 of Set 8 | mindelo
# Processing Record 30 of Set 8 | navoloki
# Processing Record 31 of Set 8 | madisonville
# Processing Record 32 of Set 8 | hegang
# Processing Record 33 of Set 8 | gobabis
# Processing Record 34 of Set 8 | ocher
# Processing Record 35 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 36 of Set 8 | mossendjo
# Processing Record 37 of Set 8 | khanty-mansiysk
# Processing Record 38 of Set 8 | susuman
# Processing Record 39 of Set 8 | bairnsdale
# Processing Record 40 of Set 8 | orbetello
# Processing Record 41 of Set 8 | ta`u
# Processing Record 42 of Set 8 | mana
# Processing Record 43 of Set 8 | okene
# Processing Record 44 of Set 8 | siwa oasis
# Processing Record 45 of Set 8 | pingliang
# Processing Record 46 of Set 8 | beloyarskiy
# Processing Record 47 of Set 8 | wanning
# Processing Record 48 of Set 8 | atherton
# Processing Record 49 of Set 8 | lukolela
# Processing Record 0 of Set 9 | atbasar
# Processing Record 1 of Set 9 | jiayuguan
# Processing Record 2 of Set 9 | goundam
# Processing Record 3 of Set 9 | woolgoolga
# Processing Record 4 of Set 9 | soio
# Processing Record 5 of Set 9 | kotzting
# Processing Record 6 of Set 9 | comodoro rivadavia
# Processing Record 7 of Set 9 | cooma
# Processing Record 8 of Set 9 | rakops
# Processing Record 9 of Set 9 | colihaut
# City not found. Skipping...
# Processing Record 10 of Set 9 | kapa'a
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | sogndal
# Processing Record 13 of Set 9 | lamu
# Processing Record 14 of Set 9 | urumita
# Processing Record 15 of Set 9 | tazacorte
# Processing Record 16 of Set 9 | qamdo
# Processing Record 17 of Set 9 | sibi
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | antigonish
# Processing Record 20 of Set 9 | chadron
# Processing Record 21 of Set 9 | katsuren-haebaru
# Processing Record 22 of Set 9 | arkhangel'sk
# Processing Record 23 of Set 9 | bishkul
# Processing Record 24 of Set 9 | lodwar
# Processing Record 25 of Set 9 | el calafate
# Processing Record 26 of Set 9 | broken hill
# Processing Record 27 of Set 9 | ciudad bolivar
# Processing Record 28 of Set 9 | tobruk
# Processing Record 29 of Set 9 | touros
# Processing Record 30 of Set 9 | kachug
# Processing Record 31 of Set 9 | boyalik
# Processing Record 32 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 33 of Set 9 | raja
# Processing Record 34 of Set 9 | belmonte
# Processing Record 35 of Set 9 | mogocha
# Processing Record 36 of Set 9 | yeed
# Processing Record 37 of Set 9 | betong
# Processing Record 38 of Set 9 | dalhart
# Processing Record 39 of Set 9 | skeldon
# Processing Record 40 of Set 9 | mugia
# Processing Record 41 of Set 9 | vadso
# Processing Record 42 of Set 9 | mili
# Processing Record 43 of Set 9 | dzhalagash
# Processing Record 44 of Set 9 | opuwo
# Processing Record 45 of Set 9 | san rafael
# Processing Record 46 of Set 9 | pagar alam
# Processing Record 47 of Set 9 | yakeshi
# Processing Record 48 of Set 9 | trenggalek
# Processing Record 49 of Set 9 | urangan
# Processing Record 0 of Set 10 | anavyssos
# Processing Record 1 of Set 10 | sechura
# Processing Record 2 of Set 10 | kidal
# Processing Record 3 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 4 of Set 10 | rasht
# Processing Record 5 of Set 10 | road town
# Processing Record 6 of Set 10 | inhambane
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | port macquarie
# Processing Record 9 of Set 10 | uturoa
# Processing Record 10 of Set 10 | kununurra
# Processing Record 11 of Set 10 | eraan
# Processing Record 12 of Set 10 | minchianabad
# Processing Record 13 of Set 10 | roma
# Processing Record 14 of Set 10 | la passe
# Processing Record 15 of Set 10 | pechora
# Processing Record 16 of Set 10 | prado
# Processing Record 17 of Set 10 | kristinestad
# Processing Record 18 of Set 10 | maple grove
# Processing Record 19 of Set 10 | sabang
# Processing Record 20 of Set 10 | hobyo
# Processing Record 21 of Set 10 | t'aebaek
# Processing Record 22 of Set 10 | sao jose da coroa grande
# Processing Record 23 of Set 10 | ataq
# Processing Record 24 of Set 10 | osterhofen
# Processing Record 25 of Set 10 | chacabuco
# Processing Record 26 of Set 10 | ulimang
# Processing Record 27 of Set 10 | alexandria
# Processing Record 28 of Set 10 | enriquillo
# Processing Record 29 of Set 10 | saint-florentin
# Processing Record 30 of Set 10 | veraval
# Processing Record 31 of Set 10 | yuanping
# Processing Record 32 of Set 10 | dilling
# Processing Record 33 of Set 10 | heunghae
# Processing Record 34 of Set 10 | halawa heights
# Processing Record 35 of Set 10 | dalbandin
# Processing Record 36 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 37 of Set 10 | playa blanca
# Processing Record 38 of Set 10 | hailey
# Processing Record 39 of Set 10 | mongoumba
# Processing Record 40 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 41 of Set 10 | chardara
# Processing Record 42 of Set 10 | dryden
# Processing Record 43 of Set 10 | sao gabriel da cachoeira
# Processing Record 44 of Set 10 | visakhapatnam
# Processing Record 45 of Set 10 | piripiri
# Processing Record 46 of Set 10 | romanovo
# Processing Record 47 of Set 10 | christchurch
# Processing Record 48 of Set 10 | kone
# Processing Record 49 of Set 10 | gereida
# Processing Record 0 of Set 11 | ceerigaabo
# Processing Record 1 of Set 11 | santa cruz do sul
# Processing Record 2 of Set 11 | rongelap
# Processing Record 3 of Set 11 | utsunomiya
# Processing Record 4 of Set 11 | bracebridge
# Processing Record 5 of Set 11 | sittwe
# Processing Record 6 of Set 11 | khawr fakkan
# Processing Record 7 of Set 11 | karkira
# Processing Record 8 of Set 11 | ar ruways
# Processing Record 9 of Set 11 | madalena
# Processing Record 10 of Set 11 | san pedro pochutla
# Processing Record 11 of Set 11 | eqbaliyeh
# Processing Record 12 of Set 11 | sanctuary point
# Processing Record 13 of Set 11 | alo
# Processing Record 14 of Set 11 | itoman
# Processing Record 15 of Set 11 | koulamoutou
# Processing Record 16 of Set 11 | talcahuano
# Processing Record 17 of Set 11 | mossel bay
# Processing Record 18 of Set 11 | galle
# Processing Record 19 of Set 11 | holualoa
# Processing Record 20 of Set 11 | yaren
# Processing Record 21 of Set 11 | ishikawa
# Processing Record 22 of Set 11 | bushland beach
# City not found. Skipping...
# Processing Record 23 of Set 11 | soure
# Processing Record 24 of Set 11 | yreka
# Processing Record 25 of Set 11 | rikaze
# Processing Record 26 of Set 11 | debre mark'os
# Processing Record 27 of Set 11 | haiku-pauwela
# Processing Record 28 of Set 11 | amol
# Processing Record 29 of Set 11 | gaspe
# Processing Record 30 of Set 11 | weno
# Processing Record 31 of Set 11 | zambezi
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | khovd
# Processing Record 34 of Set 11 | saint-flour
# Processing Record 35 of Set 11 | capilla del monte
# Processing Record 36 of Set 11 | flying fish cove
# Processing Record 37 of Set 11 | tianpeng
# Processing Record 38 of Set 11 | kuytun
# Processing Record 39 of Set 11 | porto velho
# Processing Record 40 of Set 11 | xiongzhou
# Processing Record 41 of Set 11 | parambu
# Processing Record 42 of Set 11 | taro
# Processing Record 43 of Set 11 | kailua-kona
# Processing Record 44 of Set 11 | melfort
# Processing Record 45 of Set 11 | ancud
# Processing Record 46 of Set 11 | pitkyaranta
# Processing Record 47 of Set 11 | gebeit
# Processing Record 48 of Set 11 | souillac
# Processing Record 49 of Set 11 | okhotsk
# Processing Record 0 of Set 12 | massa marittima
# Processing Record 1 of Set 12 | varzea da palma
# Processing Record 2 of Set 12 | nchelenge
# Processing Record 3 of Set 12 | derzhavinsk
# Processing Record 4 of Set 12 | columbus
# Processing Record 5 of Set 12 | baotou
# Processing Record 6 of Set 12 | lompoc
# Processing Record 7 of Set 12 | tindouf
# Processing Record 8 of Set 12 | magomeni
# Processing Record 9 of Set 12 | san antonio de pale
# Processing Record 10 of Set 12 | ouani
# Processing Record 11 of Set 12 | muisne
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | hakui
# Processing Record 14 of Set 12 | santana
# Processing Record 15 of Set 12 | jutai
# Processing Record 16 of Set 12 | el nido
# Processing Record 17 of Set 12 | sandnessjoen
# Processing Record 18 of Set 12 | el fula
# City not found. Skipping...
# Processing Record 19 of Set 12 | rurrenabaque
# Processing Record 20 of Set 12 | dinkelsbuhl
# Processing Record 21 of Set 12 | ola
# Processing Record 22 of Set 12 | timimoun
# Processing Record 23 of Set 12 | tahe
# Processing Record 24 of Set 12 | kindu
# Processing Record 25 of Set 12 | do'stlik shahri
# City not found. Skipping...
# Processing Record 26 of Set 12 | la ronge
# Processing Record 27 of Set 12 | ahar
# Processing Record 28 of Set 12 | turbo
# Processing Record 29 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 30 of Set 12 | guerrero negro
# Processing Record 31 of Set 12 | pamandzi
# Processing Record 32 of Set 12 | ust'-kut
# Processing Record 33 of Set 12 | mandalgovi
# Processing Record 34 of Set 12 | ghadamis
# Processing Record 35 of Set 12 | berezovyy
# Processing Record 36 of Set 12 | nalut
# Processing Record 37 of Set 12 | salekhard
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | khorixas
# Processing Record 40 of Set 12 | kapuskasing
# Processing Record 41 of Set 12 | lazaro cardenas
# Processing Record 42 of Set 12 | betio village
# Processing Record 43 of Set 12 | marine corps base hawaii - mcbh
# Processing Record 44 of Set 12 | itaituba
# Processing Record 45 of Set 12 | cartagena
# Processing Record 46 of Set 12 | conil de la frontera
# Processing Record 47 of Set 12 | terekli-mekteb
# Processing Record 48 of Set 12 | madang
# Processing Record 49 of Set 12 | san miguel
# Processing Record 0 of Set 13 | turochak
# Processing Record 1 of Set 13 | banda aceh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    278.30        88          68
# 1               hilo  19.7297 -155.0900    298.31        91         100
# 2           kingston  17.9970  -76.7936    306.57        66          20
# 3         gadzhiyevo  69.2551   33.3362    269.97        80          93
# 4              feijo  -8.1642  -70.3536    305.55        54         100
#
#    Wind Speed Country        Date
# 0       14.25      TF  1715276926
# 1        1.54      US  1715276926
# 2        6.17      JM  1715276385
# 3        3.15      RU  1715276927
# 4        0.82      BR  1715276927

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    278.30        88          68
# 1                     hilo  19.7297 -155.0900    298.31        91         100
# 2                 kingston  17.9970  -76.7936    306.57        66          20
# 3               gadzhiyevo  69.2551   33.3362    269.97        80          93
# 4                    feijo  -8.1642  -70.3536    305.55        54         100
#
#          Wind Speed Country        Date
# City_ID
# 0             14.25      TF  1715276926
# 1              1.54      US  1715276926
# 2              6.17      JM  1715276385
# 3              3.15      RU  1715276927
# 4              0.82      BR  1715276927

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values,edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
plt.grid=True
plt.show()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values,edgecolors='black')
plt.xlabel('Latitude)')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.grid=True
plt.show()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values,edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.grid=True
plt.show()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values,edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.grid=True
plt.show()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x, y):
    Parameters:
    - x: Independent variable (e.g., x-axis data)
    - y: Dependent variable (e.g., y-axis data)
# Out:
#   Cell In[34], line 2
#     def create_linear_regression_plot(x, y):
#                                             ^
# SyntaxError: incomplete input

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hem_data = city_data_df(Latitude >= 0)

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
